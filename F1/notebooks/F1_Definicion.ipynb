# %% [markdown]
# # Fase 1 - Definicion y entorno reproducible
# Proyecto: Proyecto ABP - Ciencia de Datos Reproducible
#
# Este notebook documenta la implementacion inicial del entorno reproducible, la problematica, objetivos y trazabilidad tecnica.

# %% [markdown]
# ## 1. Contexto y problematica
# El proyecto aborda la necesidad de construir un flujo reproducible de ciencia de datos para analizar un conjunto de datos asignado al equipo, documentando el contexto, las decisiones tÃ©cnicas y el valor analÃ­tico esperado. La problemÃ¡tica se centra en transformar datos iniciales en informaciÃ³n confiable mediante exploraciÃ³n, limpieza, validaciÃ³n y trazabilidad con Python, Jupyter, Pandas, NumPy y Git/GitHub, de modo que el trabajo pueda ser revisado, replicado y ampliado por todos los integrantes en las fases posteriores.

# %% [markdown]
# ## 2. Objetivos
# **Objetivo general:** construir un flujo reproducible de obtencion, limpieza y transformacion de datos utilizando Python, Jupyter, Pandas, NumPy y GitHub.
#
# **Objetivos especificos:**
# - Configurar un repositorio reproducible con Git/GitHub.
# - Documentar dependencias, entorno de ejecuciÃ³n y estructura del proyecto.
# - Separar responsabilidades mediante mÃ³dulos reutilizables en `F1/src`.
# - Validar que la definiciÃ³n de la problemÃ¡tica tenga contenido suficiente y no sea un marcador de relleno.
# - Dejar una base tÃ©cnica trazable para continuar con exploraciÃ³n, limpieza y anÃ¡lisis en fases posteriores.

# %% [markdown]
# ## 3. Validacion del entorno
# Se registran versiones de Python y librerias para asegurar reproducibilidad.

# %%
import sys
from pathlib import Path
import numpy as np
import pandas as pd
print('Python:', sys.version.split()[0])
print('NumPy:', np.__version__)
print('Pandas:', pd.__version__)
print('Directorio:', Path.cwd())

# %% [markdown]
# ## 4. Modularidad inicial
# Se importa una funcion desde F1/src, evidenciando separacion minima de responsabilidades.

# %%
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parents[1]
sys.path.append(str(ROOT / 'F1' / 'src'))
from f1_utils import environment_snapshot, validate_problem_statement  # noqa: E402
environment_snapshot()

# %%
problematica = """


El proyecto aborda la necesidad de construir un flujo reproducible de ciencia de datos para analizar un conjunto de datos asignado al equipo, documentando el contexto, las decisiones tÃ©cnicas y el valor analÃ­tico esperado. La problemÃ¡tica se centra en transformar datos iniciales en informaciÃ³n confiable mediante exploraciÃ³n, limpieza, validaciÃ³n y trazabilidad con Python, Jupyter, Pandas, NumPy y Git/GitHub, de modo que el trabajo pueda ser revisado, replicado y ampliado por todos los integrantes en las fases posteriores.


"""





assert validate_problem_statement(problematica), "La problemÃ¡tica debe estar mejor desarrollada."


print("ProblemÃ¡tica validada para F1")

# %% [markdown]
# ## 5. Vinculacion con mapa conceptual
# Completar en el informe: indicar que componentes del mapa se materializan en repositorio, notebook, README, dependencias, Git/GitHub y que elementos quedan proyectados para F2-F4.
